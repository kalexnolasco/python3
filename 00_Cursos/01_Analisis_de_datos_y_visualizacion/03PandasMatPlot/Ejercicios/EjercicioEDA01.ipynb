# %% [markdown]
# ![image.png](data:image/png;base64,...)
# # Ejercicio Analisis Exploratorio de Datos
# <BR>
# Empezamos con el primer analisis exploratorio de datos. Conoceremos el dataset y luego encontraremos informacion util sobre los datos que encontramos.<BR>
# Si bien es importante conocer las instrucciones que nos permiten hacer el analisis y la visualizacion, tambien es muy importante interpretar las graficas lo mas profundo posible para convertir los datos en informacion que podamos dar

# %%
## Importamos pandas numpy y matplotlib
import 
import 
import

# %%
## Leemos el dataset
df=
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Exploramos el dataset

# %%
## Vemos el tmanano del dataset
df.
# Out:
# (153, 6)

# %%
## Vemos las caracteristicas de sus columnas
## Que nos indican cada tipo de dato?
## Hay datos faltantes?
## Que tipos de datos numericos tenemos?
df.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             153 non-null    int64
#  1   SepalLengthCm  153 non-null    float64
#  2   SepalWidthCm   153 non-null    float64
#  3   PetalLengthCm  153 non-null    float64
#  4   PetalWidthCm   153 non-null    float64
#  5   Species        153 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.3+ KB

# %%
## Obtenemos la informacion estadistica basica
## Que podemos conocer a partir de esos valores?
df.
# Out:
#                count       mean        std  min   25%   50%    75%    max
# Id             153.0  77.000000  44.311398  1.0  39.0  77.0  115.0  153.0
# SepalLengthCm  153.0   5.828758   0.828019  4.3   5.1   5.8    6.4    7.9
# SepalWidthCm   153.0   3.054248   0.429502  2.0   2.8   3.0    3.3    4.4
# PetalLengthCm  153.0   3.732680   1.764408  1.0   1.6   4.3    5.1    6.9
# PetalWidthCm   153.0   1.186275   0.764170  0.1   0.3   1.3    1.8    2.5

# %%
## Encontramos los valores unicos de las especies
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
## Exploramos is las otras caracteristicas tienen valores comunes o son totalmente continuos
print('Cantidad de valores en SepalLengthCM',)
print('Cantidad de valores en SepalWidthCm',)
print('Cantidad de valores en PetalLengthCm',)
print('Cantidad de valores en PetalWidthCm',)
# Out:
# Cantidad de valores en SepalLengthCM 35
# Cantidad de valores en SepalWidthCm 23
# Cantidad de valores en PetalLengthCm 43
# Cantidad de valores en PetalWidthCm 22

# %%
## Verificamos la cantidad  valores duplicados
## Como un valor duplicado debe de tener TODAS las columnas iguales pero Id tiene valores unicos
## Usamos solamente las columnas que nos dan informacion relevante
df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']].
# Out:
# 6

# %%
## mostramos los valroes duplicados
df[df[].]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 34    35            4.9           3.1            1.5           0.1
# 37    38            4.9           3.1            1.5           0.1
# 142  143            5.8           2.7            5.1           1.9
# 150  151            4.7           3.2            1.6           0.2
# 151  152            5.0           3.0            1.6           0.2
# 152  153            5.6           3.0            4.1           1.3
#
#              Species
# 34       Iris-setosa
# 37       Iris-setosa
# 142   Iris-virginica
# 150      Iris-setosa
# 151      Iris-setosa
# 152  Iris-versicolor

# %%
## Buscamos valores faltantes
df.
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # Visualizaciones
#
# Para cada visualizacion escribir una descripcion de lo que se ha encontrado

# %%
## Observamos la cantidad de cada especie, usar pandas
df['Species'].
# Out:
# <AxesSubplot:>

# %%
## Visualizamos las relaciones entre las variables, usar pandas, ver las variables a usar en cada imagen
df.
df.
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='SepalWidthCm'>

# %%
## Parecen haber grupos separados, seria bueno saber si la especie influye en eso
## Crear tres dataframes, uno para cada especie 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'

# Eliminamos Id pues ya no lo usaremos

df.drop('Id', axis=1, inplace=True)

dfSetosa=
dfVersicolor=
dfVirginica=

# %%
## Para setosa
dfSetosa.
dfSetosa.
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='SepalWidthCm'>

# %%
## Para versicolor
dfVersicolor.
dfVersicolor.
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='SepalWidthCm'>

# %%
## Para virginica
dfVirginica.
dfVirginica.
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='SepalWidthCm'>

# %%
## Observamos los boxplots de las variables, usar pandas

df.
# Out:
# <AxesSubplot:>

# %%
## Lo hacemos para cada especie
dfSetosa.
# Out:
# <AxesSubplot:>

# %%
## Ahora para versicolor
dfVersicolor.
# Out:
# <AxesSubplot:>

# %%
## Por ultimo para virginica
dfVirginica.
# Out:
# <AxesSubplot:>

# %%
## vemos la distribucion de SepalLengthCm del dataset
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
## vemos la distribucion de SepalWidthCm del dataset
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
## vemos el histograma de PetalLengthCm, 20 bins
# Out:
# <AxesSubplot:>

# %%
## Vemos el histograma de PetalWidthCm, 20 bins
# Out:
# <AxesSubplot:>
